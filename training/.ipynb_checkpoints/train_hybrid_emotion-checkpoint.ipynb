# %%
# ============================================================
# CELL 1 — Imports and CPU Setup
# Forces CPU usage (prevents GPU instability issues)
# ============================================================

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization, Concatenate
)

# %%
# ============================================================
# CELL 2 — Dynamic Project Root Detection
# Ensures correct paths regardless of working directory
# ============================================================

# Detect project root dynamically
if os.path.basename(os.getcwd()) == "training":
    PROJECT_ROOT = os.path.dirname(os.getcwd())
else:
    PROJECT_ROOT = os.getcwd()

DATASET_PATH = os.path.join(PROJECT_ROOT, "data", "DEAM", "DEAM_audio", "MEMD_audio")

ANNOTATION_PATH_1 = os.path.join(
    PROJECT_ROOT,
    "data", "DEAM", "DEAM_Annotations", "annotations",
    "annotations averaged per song", "song_level",
    "static_annotations_averaged_songs_1_2000.csv"
)

ANNOTATION_PATH_2 = os.path.join(
    PROJECT_ROOT,
    "data", "DEAM", "DEAM_Annotations", "annotations",
    "annotations averaged per song", "song_level",
    "static_annotations_averaged_songs_2000_2058.csv"
)

print("Project Root:", PROJECT_ROOT)
print("Dataset Exists:", os.path.exists(DATASET_PATH))
print("Audio Files:", len(os.listdir(DATASET_PATH)))
# Out:
# Project Root: C:\Users\adith\Documents\Study\Coding\Muud
# Dataset Exists: True
# Audio Files: 1802

# %%
# ============================================================
# CELL 3 — Load and Clean Annotation Files
# Keeps only song_id, valence_mean, arousal_mean
# ============================================================

ann1 = pd.read_csv(ANNOTATION_PATH_1)
ann2 = pd.read_csv(ANNOTATION_PATH_2)

annotations = pd.concat([ann1, ann2], ignore_index=True)

# Remove leading/trailing spaces in column names
annotations.columns = annotations.columns.str.strip()

annotations = annotations[["song_id", "valence_mean", "arousal_mean"]]

# Ensure song_id is integer
annotations["song_id"] = annotations["song_id"].astype(int)

print("Total annotated songs:", len(annotations))
annotations.head()
# Out:
# Total annotated songs: 1802
#    song_id  valence_mean  arousal_mean
# 0        2           3.1           3.0
# 1        3           3.5           3.3
# 2        4           5.7           5.5
# 3        5           4.4           5.3
# 4        7           5.8           6.4

# %%
# ============================================================
# CELL 4 — Audio Processing Constants
# ============================================================

SAMPLE_RATE = 22050
SEGMENT_DURATION = 3
SAMPLES_PER_SEGMENT = SAMPLE_RATE * SEGMENT_DURATION
N_MELS = 128
MAX_SEGMENTS = 10

print("Samples per segment:", SAMPLES_PER_SEGMENT)
# Out:
# Samples per segment: 66150

# %%
# ============================================================
# CELL 5 — Extract Mel Spectrogram + Handcrafted Features
# Returns:
#   - Mel spectrogram segments
#   - Handcrafted features (tempo, centroid, rms, zcr)
#   - Valence & arousal labels
# ============================================================

def extract_features_with_stats(file_path, valence, arousal):
    segments = []
    handcrafted = []
    labels = []

    try:
        signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

        # Extract tempo ONCE per song (expensive operation — avoid per-segment)
        tempo, _ = librosa.beat.beat_track(y=signal, sr=sr)
        tempo = float(np.squeeze(tempo))  # Newer librosa returns array, force scalar

        total_samples = len(signal)
        num_segments = total_samples // SAMPLES_PER_SEGMENT

        for s in range(min(num_segments, MAX_SEGMENTS)):
            start = s * SAMPLES_PER_SEGMENT
            end = start + SAMPLES_PER_SEGMENT
            segment = signal[start:end]

            # -------- Mel Spectrogram --------
            mel = librosa.feature.melspectrogram(
                y=segment,
                sr=sr,
                n_mels=N_MELS
            )

            mel = librosa.power_to_db(mel)

            if np.std(mel) != 0:
                mel = (mel - np.mean(mel)) / np.std(mel)

            # -------- Handcrafted Features (per segment) --------
            centroid = float(np.mean(librosa.feature.spectral_centroid(y=segment, sr=sr)))
            rms = float(np.mean(librosa.feature.rms(y=segment)))
            zcr = float(np.mean(librosa.feature.zero_crossing_rate(segment)))

            segments.append(mel)
            handcrafted.append([tempo, centroid, rms, zcr])
            labels.append([valence, arousal])

        return segments, handcrafted, labels

    except Exception as e:
        print("Error processing:", file_path)
        print(e)
        return [], [], []

# %%
# ============================================================
# CELL 6 — Build Full Dataset
# ============================================================

X_mel = []
X_stats = []
y = []

for _, row in annotations.iterrows():
    song_id = int(row["song_id"])  # Force int — iterrows() silently converts to float!
    valence = row["valence_mean"]
    arousal = row["arousal_mean"]

    file_path = os.path.join(DATASET_PATH, f"{song_id}.mp3")

    if os.path.exists(file_path):
        mel, stats, labels = extract_features_with_stats(
            file_path, valence, arousal
        )

        X_mel.extend(mel)
        X_stats.extend(stats)
        y.extend(labels)

print("Total segments created:", len(X_mel))
# Out:
# Total segments created: 18020

# %%
# ============================================================
# CELL 7 — Convert Lists to NumPy Arrays
# ============================================================

X_mel = np.array(X_mel)[..., np.newaxis]
X_stats = np.array(X_stats)
y = np.array(y)

print("Mel shape:", X_mel.shape)
print("Stats shape:", X_stats.shape)
print("Labels shape:", y.shape)
# Out:
# Mel shape: (18020, 128, 130, 1)
# Stats shape: (18020, 4)
# Labels shape: (18020, 2)

# %%
# ============================================================
# CELL 8 — Train/Test Split
# ============================================================

X_train_mel, X_test_mel, X_train_stats, X_test_stats, y_train, y_test = train_test_split(
    X_mel, X_stats, y,
    test_size=0.2,
    random_state=42
)

print("Train samples:", len(X_train_mel))
print("Test samples:", len(X_test_mel))
# Out:
# Train samples: 14416
# Test samples: 3604

# %%
# ============================================================
# CELL 9 — Hybrid CNN + Handcrafted Feature Fusion Model
# ============================================================

# -------- Mel Input Branch --------
mel_input = Input(shape=X_train_mel.shape[1:])

x = Conv2D(32, (3,3), activation='relu')(mel_input)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)

# -------- Handcrafted Input Branch --------
stats_input = Input(shape=(4,))
s = Dense(16, activation='relu')(stats_input)

# -------- Fusion Layer --------
combined = Concatenate()([x, s])

z = Dense(128, activation='relu')(combined)
z = Dropout(0.4)(z)

output = Dense(2)(z)

model = Model(inputs=[mel_input, stats_input], outputs=output)

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mae']
)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 130, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 126, 128, 32  320         ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 64, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 61, 62, 64)   18496       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 31, 64)  0           ['conv2d_1[0][0]']
#
#  input_2 (InputLayer)           [(None, 4)]          0           []
#
#  flatten (Flatten)              (None, 59520)        0           ['max_pooling2d_1[0][0]']
#
#  dense (Dense)                  (None, 16)           80          ['input_2[0][0]']
#
#  concatenate (Concatenate)      (None, 59536)        0           ['flatten[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 128)          7620736     ['concatenate[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 2)            258         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 7,639,890
# Trainable params: 7,639,890
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# ============================================================
# CELL 10 — Train Hybrid Model
# ============================================================

history = model.fit(
    [X_train_mel, X_train_stats],
    y_train,
    validation_data=([X_test_mel, X_test_stats], y_test),
    epochs=40,
    batch_size=16
)
# Out:
# Epoch 1/40
# 901/901 [==============================] - 79s 87ms/step - loss: 5.2615 - mae: 1.6124 - val_loss: 1.1352 - val_mae: 0.8546
# Epoch 2/40
# 901/901 [==============================] - 82s 92ms/step - loss: 2.8919 - mae: 1.3500 - val_loss: 1.0310 - val_mae: 0.8118
# Epoch 3/40
# 901/901 [==============================] - 80s 89ms/step - loss: 2.5597 - mae: 1.2725 - val_loss: 0.9606 - val_mae: 0.7840
# Epoch 4/40
# 901/901 [==============================] - 82s 91ms/step - loss: 2.1673 - mae: 1.1698 - val_loss: 1.0931 - val_mae: 0.8366
# Epoch 5/40
# 901/901 [==============================] - 79s 88ms/step - loss: 1.8303 - mae: 1.0739 - val_loss: 1.3963 - val_mae: 0.9597
# Epoch 6/40
# 901/901 [==============================] - 78s 86ms/step - loss: 1.6343 - mae: 1.0142 - val_loss: 0.8951 - val_mae: 0.7590
# Epoch 7/40
# 901/901 [==============================] - 80s 89ms/step - loss: 1.3678 - mae: 0.9322 - val_loss: 0.9357 - val_mae: 0.7768
# Epoch 8/40
# 901/901 [==============================] - 83s 92ms/step - loss: 1.1931 - mae: 0.8747 - val_loss: 0.8567 - val_mae: 0.7445
# Epoch 9/40
# 901/901 [==============================] - 84s 93ms/step - loss: 1.0688 - mae: 0.8249 - val_loss: 0.8302 - val_mae: 0.7296
# Epoch 10/40
# 901/901 [==============================] - 84s 93ms/step - loss: 0.9628 - mae: 0.7857 - val_loss: 0.8424 - val_mae: 0.7351
# Epoch 11/40
# 901/901 [==============================] - 77s 86ms/step - loss: 0.8782 - mae: 0.7513 - val_loss: 0.8279 - val_mae: 0.7297
# Epoch 12/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.8144 - mae: 0.7225 - val_loss: 0.8240 - val_mae: 0.7261
# Epoch 13/40
# 901/901 [==============================] - 69s 76ms/step - loss: 0.7784 - mae: 0.7066 - val_loss: 0.8222 - val_mae: 0.7259
# Epoch 14/40
# 901/901 [==============================] - 72s 79ms/step - loss: 0.7364 - mae: 0.6875 - val_loss: 0.8780 - val_mae: 0.7583
# Epoch 15/40
# 901/901 [==============================] - 72s 80ms/step - loss: 0.7092 - mae: 0.6710 - val_loss: 0.8494 - val_mae: 0.7391
# Epoch 16/40
# 901/901 [==============================] - 70s 77ms/step - loss: 0.6780 - mae: 0.6549 - val_loss: 0.8397 - val_mae: 0.7314
# Epoch 17/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.6405 - mae: 0.6366 - val_loss: 0.8434 - val_mae: 0.7368
# Epoch 18/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.6144 - mae: 0.6218 - val_loss: 0.8566 - val_mae: 0.7435
# Epoch 19/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.5897 - mae: 0.6070 - val_loss: 0.8233 - val_mae: 0.7234
# Epoch 20/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.5594 - mae: 0.5910 - val_loss: 0.8259 - val_mae: 0.7185
# Epoch 21/40
# 901/901 [==============================] - 73s 81ms/step - loss: 0.5229 - mae: 0.5682 - val_loss: 0.8191 - val_mae: 0.7185
# Epoch 22/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.4967 - mae: 0.5514 - val_loss: 0.8439 - val_mae: 0.7348
# Epoch 23/40
# 901/901 [==============================] - 71s 78ms/step - loss: 0.4867 - mae: 0.5424 - val_loss: 0.8198 - val_mae: 0.7198
# Epoch 24/40
# 901/901 [==============================] - 72s 79ms/step - loss: 0.4663 - mae: 0.5298 - val_loss: 0.8244 - val_mae: 0.7255
# Epoch 25/40
# 901/901 [==============================] - 71s 78ms/step - loss: 0.4581 - mae: 0.5222 - val_loss: 0.8248 - val_mae: 0.7236
# Epoch 26/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.4444 - mae: 0.5147 - val_loss: 0.8430 - val_mae: 0.7335
# Epoch 27/40
# 901/901 [==============================] - 71s 78ms/step - loss: 0.4271 - mae: 0.5025 - val_loss: 0.8120 - val_mae: 0.7179
# Epoch 28/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.4101 - mae: 0.4919 - val_loss: 0.7916 - val_mae: 0.7037
# Epoch 29/40
# 901/901 [==============================] - 72s 79ms/step - loss: 0.3997 - mae: 0.4840 - val_loss: 0.8148 - val_mae: 0.7153
# Epoch 30/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.3931 - mae: 0.4782 - val_loss: 0.8116 - val_mae: 0.7108
# Epoch 31/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.3825 - mae: 0.4712 - val_loss: 0.8203 - val_mae: 0.7176
# Epoch 32/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.3790 - mae: 0.4686 - val_loss: 0.8192 - val_mae: 0.7152
# Epoch 33/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3757 - mae: 0.4645 - val_loss: 0.8309 - val_mae: 0.7272
# Epoch 34/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3647 - mae: 0.4580 - val_loss: 0.8076 - val_mae: 0.7112
# Epoch 35/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3590 - mae: 0.4534 - val_loss: 0.8015 - val_mae: 0.7099
# Epoch 36/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3509 - mae: 0.4495 - val_loss: 0.8210 - val_mae: 0.7221
# Epoch 37/40
# 901/901 [==============================] - 71s 79ms/step - loss: 0.3586 - mae: 0.4518 - val_loss: 0.8024 - val_mae: 0.7091
# Epoch 38/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3546 - mae: 0.4510 - val_loss: 0.8179 - val_mae: 0.7197
# Epoch 39/40
# 901/901 [==============================] - 69s 77ms/step - loss: 0.3440 - mae: 0.4431 - val_loss: 0.8072 - val_mae: 0.7105
# Epoch 40/40
# 901/901 [==============================] - 70s 78ms/step - loss: 0.3454 - mae: 0.4430 - val_loss: 0.8053 - val_mae: 0.7098

# %%
# ============================================================
# CELL 11 — Plot Training Curves
# ============================================================

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("MSE Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history["mae"], label="Train MAE")
plt.plot(history.history["val_mae"], label="Val MAE")
plt.title("MAE")
plt.legend()

plt.show()

# %%
# ============================================================
# CELL 12 — Save Trained Model
# ============================================================

model.save(os.path.join(PROJECT_ROOT, "models", "emotion_hybrid_model.keras"))
print("Model saved successfully.")
# Out:
# Model saved successfully.
